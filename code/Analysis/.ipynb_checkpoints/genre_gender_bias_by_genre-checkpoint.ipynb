# %% [markdown]
# This notebook calculates the following:
# ### <p><center>For each genre, what is the gender split among all artists that are labeled with that genre?</center></p>
#
# - Part 1 compiles a dataframe ('genre_stats') with this information along with some other stats on each genre label from the training set.
# - Part 2 further analyzes this information.
#
# Unless something needs to be recalculated, start at Part 2 where a copy of the dataframe 'genre_stats' is imported; the calculation of it is ~5 min.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline
#%matplotlib notebook


import re

from functools import partial

import plotly.graph_objects as go

# %% [markdown]
# # Part 1

# %% [markdown]
# Import the cleaned data:

# %%
#%ls -lt ../../data/genre_lists/data_ready_for_model/

# %%
# %store -r now
now
#now = '2020-05-11-14-35'
# Out:
# '2020-05-18-10-06'

# %%
X_train = pd.read_csv('/Users/Daniel/Code/Genre/data/genre_lists/data_ready_for_model/wiki-kaggle_X_train_{}.csv'.format(now), index_col = ['artist'])
y_train = pd.read_csv('/Users/Daniel/Code/Genre/data/genre_lists/data_ready_for_model/wiki-kaggle_y_train_{}.csv'.format(now), index_col = ['artist'])

# %% [markdown]
# ### Genre Labels -- as a list
#
# Each value of the genre column is a _string_ of comma separated genre labels using the spotify abbreviations. We want to convert it to a _list_ of strings.

# %%
"""This function takes in a string of the form
appearing in the genrelist of the dataframe.
It strips the square brackets and extra quotes and
returns a list of strings where each string is a genre label."""
def genrelist(string):
    string = string.strip("[").strip("]").replace("'","")
    L = [s for s in string.split(',')]
    L_new = []
    for x in L:
        L_new.append(x.replace(" ","_").lstrip("_").rstrip("_"))
    while (str("") in L_new):
        L_new.remove("")
    return L_new

# %% [markdown]
# Now we apply
# - it to the whole column and put the lists in a new column
# - assemble X,y into DF
# -reset index to 'artist_id'

# %%
X_train['genrelist']= X_train['genrelist'].apply(genrelist)

data = X_train.join(y_train, how = 'inner', on = 'artist')

data.reset_index(inplace = True)
data.index.name = 'artist_id'
data_set_size = data.shape[0]

# %% [markdown]
# - Full genre_list (not just that for the training set)
# - Vocab Dict and Size
# - max length of lists

# %%
genre_list = pd.read_csv('/Users/Daniel/Code/Genre/data/genre_lists/data_ready_for_model/genre_list_{}.csv'.format(now))
genre_list.drop(['Unnamed: 0'], axis = 1, inplace = True)
genre_list['genre_id'] = list(range(1,genre_list.shape[0]+1))

#Size of the vocab:
vocab_size = genre_list.shape[0]

#Create a dictionary {genre_label: genre_id}
label_id_dict = genre_list.set_index(['genre_list'])['genre_id'].to_dict()
id_label_dict = genre_list.set_index(['genre_id'])['genre_list'].to_dict()



#Find max length of genre lists:
max_list_length = data.genrelist_length.max()

# %% [markdown]
# ### Count thefrequency of each label and prepare other columns
#
# (This deals only with the training data, not the test data.)

# %%
genre_list_1 = data.genrelist.values.tolist()
genre_list_1 = [x for y in genre_list_1 for x in y]
genre_counts = pd.Series(genre_list_1, name = 'frequency')
genre_stats = genre_counts.value_counts().to_frame()
genre_stats.index.name = 'label'

# %%
# encode labels as ints within the list
def encode_list(row):
    return [label_id_dict[item] for item in row.genrelist]

data['genres_encoded_as_list'] = data.apply(encode_list, axis = 1)

#Check that the encoding is consistent: 
# n = np.random.randint(data.shape[0])
# [label_id_dict[item] for item in data.genrelist.iloc[n]], data.genres_encoded_as_list.iloc[n]

# Encode targets. The categories still appear as strings. To see the encoding use df.column.cat.codes.
data['gender'] = data.gender.apply(lambda x: 1 if x == 'female' else 0)

# %%
max_num_male = 73
max_num_female = 11
max_num = max(max_num_female, max_num_male)

# %% [markdown]
# ### Stats by that genre label
# - [ ] do this using sparse dataframe with one-hot encoding for speed up?

# %%
# fnc used with apply to data to select artists with a given label
def indicate(row):
    if label in row.genrelist:
        return 1
    else:
        return 0

# %%
data.columns
# Out:
# Index(['artist', 'genrelist', 'genrelist_length', 'gender',
#        'genres_encoded_as_list'],
#       dtype='object')

# %%
# produce stats for each label: male, female; mean number of labels; max, min number of labels
idx_list = []
for label in genre_stats.index: # use labels ordered by their frequency of appearance
    data['indicator'] = data.apply(indicate, axis = 1)
    label_artists = data[data.indicator == 1]
    genre_stats.loc[label,'female'] = int(label_artists.gender.sum())
    genre_stats.loc[label,'male'] = label_artists.shape[0]-label_artists.gender.sum()
    genre_stats.loc[label,'max_list_length'] = label_artists.genrelist_length.max()
    genre_stats.loc[label,'min_list_length'] = label_artists.genrelist_length.min()
    genre_stats.loc[label,'mean_list_length'] = label_artists.genrelist_length.mean()
    #data.drop(['indicator'], inplace = True)

# calculated columns
genre_stats['female%'] = genre_stats['female']/genre_stats['frequency']
genre_stats['male%'] = genre_stats['male']/genre_stats['frequency']
# reorder columns
genre_stats = genre_stats[['frequency','female','male','female%','male%','max_list_length','min_list_length','mean_list_length']]

# %% [markdown]
# Write to csv:

# %%
genre_stats.to_csv('/Users/Daniel/Code/Genre/data/genre_lists/data_ready_for_model/genre_stats.csv')

# %% [markdown]
# # Part 2

# %%
genre_stats = pd.read_csv('/Users/Daniel/Code/Genre/data/genre_lists/data_ready_for_model/genre_stats.csv', index_col = 'label')

# %%
genre_stats.head()
# Out:
#          frequency  female    male   female%     male%  max_list_length  \
# label
# pop           2617  1321.0  1294.0  0.504776  0.494459             73.0
# rock          1765   356.0  1409.0  0.201700  0.798300             13.0
# r_and_b       1647   760.0   887.0  0.461445  0.538555             13.0
# country       1613   504.0  1108.0  0.312461  0.686919             12.0
# hip_hop       1114   187.0   927.0  0.167864  0.832136             73.0
#
#          min_list_length  mean_list_length
# label
# pop                  1.0          3.065392
# rock                 1.0          3.373371
# r_and_b              1.0          3.585914
# country              1.0          2.358561
# hip_hop              1.0          2.538600

# %% [markdown]
# Overall ratio to total of female and male artists:

# %%
f_ratio = data.gender.sum()/data.shape[0]
m_ratio = (1-data.gender).sum()/data.shape[0]
f_ratio, m_ratio
# Out:
# (0.3108435681965094, 0.6891564318034906)

# %%
genre_stats['f-skew'] = genre_stats['female%']/f_ratio
genre_stats['m-skew'] = genre_stats['male%']/m_ratio

# %% [markdown]
# Rank genres (with frequency >= 100) by male-skew descending:

# %%
genre_stats[(genre_stats.frequency >= 100) & (genre_stats['m-skew'] > 1)].sort_values(['m-skew'], ascending = False)
# Out:
#                    frequency  female    male   female%     male%  \
# label
# hardcore_punk            135     5.0   130.0  0.037037  0.962963
# progressive_rock         227     9.0   218.0  0.039648  0.960352
# hard_rock                616    42.0   574.0  0.068182  0.931818
# heavy_metal              453    34.0   419.0  0.075055  0.924945
# rockabilly               129    10.0   119.0  0.077519  0.922481
# jazz_fusion              122    11.0   111.0  0.090164  0.909836
# alternative_metal        148    14.0   134.0  0.094595  0.905405
# blues_rock               335    31.0   303.0  0.092537  0.904478
# electric_blues           156    15.0   141.0  0.096154  0.903846
# rock_and_roll            299    29.0   270.0  0.096990  0.903010
# psychedelic_rock         171    17.0   154.0  0.099415  0.900585
# experimental_rock        122    14.0   108.0  0.114754  0.885246
# post_punk                160    22.0   138.0  0.137500  0.862500
# country_rock             164    23.0   141.0  0.140244  0.859756
# power_pop                115    17.0    98.0  0.147826  0.852174
# hip_hop                 1114   187.0   927.0  0.167864  0.832136
# art_rock                 113    20.0    93.0  0.176991  0.823009
# punk_rock                369    67.0   302.0  0.181572  0.818428
# experimental             152    29.0   123.0  0.190789  0.809211
# soft_rock                171    33.0   138.0  0.192982  0.807018
# bluegrass                153    30.0   123.0  0.196078  0.803922
# rock                    1765   356.0  1409.0  0.201700  0.798300
# classical                162    34.0   128.0  0.209877  0.790123
# pop_punk                 118    25.0    93.0  0.211864  0.788136
# alternative_rock         937   199.0   737.0  0.212380  0.786553
# blues                    859   191.0   668.0  0.222352  0.777648
# reggae                   133    32.0   101.0  0.240602  0.759398
# new_wave                 298    73.0   225.0  0.244966  0.755034
# funk                     298    80.0   218.0  0.268456  0.731544
# indie_rock               495   134.0   361.0  0.270707  0.729293
# folk_rock                403   114.0   289.0  0.282878  0.717122
# acoustic                 145    44.0   101.0  0.303448  0.696552
# world                    129    40.0    89.0  0.310078  0.689922
#
#                    max_list_length  min_list_length  mean_list_length  \
# label
# hardcore_punk                 11.0              1.0          4.459259
# progressive_rock              73.0              1.0          4.453744
# hard_rock                     73.0              1.0          4.150974
# heavy_metal                   15.0              1.0          4.090508
# rockabilly                    14.0              1.0          4.062016
# jazz_fusion                   45.0              2.0          4.737705
# alternative_metal             12.0              1.0          4.959459
# blues_rock                    12.0              1.0          4.227545
# electric_blues                 9.0              1.0          2.532051
# rock_and_roll                 12.0              1.0          3.698997
# psychedelic_rock              11.0              2.0          4.690058
# experimental_rock             15.0              1.0          5.000000
# post_punk                     15.0              1.0          4.475000
# country_rock                  11.0              1.0          4.378049
# power_pop                     10.0              1.0          3.973913
# hip_hop                       73.0              1.0          2.538600
# art_rock                      73.0              2.0          5.407080
# punk_rock                     14.0              1.0          3.989160
# pop_rock                   661   231.0   426.0  0.349470  0.644478
# alternative_country        147    46.0   101.0  0.312925  0.687075
# country                   1613   504.0  1108.0  0.312461  0.686919
#
#                      max_list_length  min_list_length  mean_list_length  \
# label
# dance_pop                        9.0              1.0          3.754098
# electro_pop                     10.0              1.0          3.910569
# dance                           73.0              1.0          4.205212
# house                           14.0              1.0          4.195804
# disco                           73.0              1.0          5.061224
# indie_pop                       73.0              1.0          3.651261
# soul                            13.0              1.0          3.894325
# pop                             73.0              1.0          3.065392
# alternative                     11.0              1.0          3.575000
# gospel                          12.0              1.0          3.936416
# r_and_b                         13.0              1.0          3.585914
# electronica                     15.0              1.0          4.430851
# folk                            12.0              1.0          3.384468
# jazz                            12.0              1.0          3.415800
# electronic                      15.0              1.0          4.250000
# americana                       12.0              1.0          4.133333
# indie_folk                      12.0              1.0          3.647059
# synth_pop                       73.0              1.0          4.823529
# pop_rock                        14.0              1.0          3.838661
# alternative_country             10.0              1.0          3.768707
# country                         12.0              1.0          2.358561
#
#                        f-skew    m-skew
# label
# dance_pop            2.338076  0.396462
# electro_pop          2.170856  0.471886
# dance                2.137716  0.486834
# house                2.114706  0.497213
# disco                1.925854  0.582394
# indie_pop            1.905901  0.591394
# soul                 1.672993  0.695029
# pop                  1.623892  0.717485
# alternative          1.554909  0.749709
# gospel               1.506250  0.771656
# r_and_b              1.484493  0.781470
# electronica          1.454518  0.794990
# folk                 1.313271  0.854538
# jazz                 1.310899  0.859769
# electronic           1.292566  0.868038
# americana            1.203416  0.908249
# indie_folk           1.198510  0.910462
# synth_pop            1.151200  0.931801
# pop_rock             1.124265  0.935169
# alternative_country  1.006697  0.996979
# country              1.005204  0.996753

# %% [markdown]
# Rank genres (with frequency >= 50) by absolute male-ness descending:

# %%
genre_stats[(genre_stats.frequency >= 50) & (genre_stats['m-skew'] > 1)].sort_values(['male%'], ascending = False)
# Out:
#                      frequency  female    male   female%     male%  \
# label
# post_hardcore               87     1.0    86.0  0.011494  0.988506
# death_metal                 71     1.0    70.0  0.014085  0.985915
# progressive_metal           87     2.0    85.0  0.022989  0.977011
# gangsta_rap                 68     2.0    66.0  0.029412  0.970588
# thrash_metal                98     3.0    95.0  0.030612  0.969388
# emo                         62     2.0    60.0  0.032258  0.967742
# hardcore_punk              135     5.0   130.0  0.037037  0.962963
# progressive_rock           227     9.0   218.0  0.039648  0.960352
# power_metal                 63     3.0    60.0  0.047619  0.952381
# southern_rock               90     5.0    85.0  0.055556  0.944444
# metalcore                   66     4.0    62.0  0.060606  0.939394
# nu_metal                    82     5.0    77.0  0.060976  0.939024
# alternative_hip_hop         78     5.0    73.0  0.064103  0.935897
# chicago_blues               75     5.0    70.0  0.066667  0.933333
# hard_rock                  616    42.0   574.0  0.068182  0.931818
# glam_metal                  85     6.0    79.0  0.070588  0.929412
# trap                        56     4.0    52.0  0.071429  0.928571
# experimental_rock    0.369170  1.284535
# post_grunge          0.389946  1.275165
# country_blues        0.417799  1.262601
# texas_blues          0.441556  1.251886
# post_punk            0.442345  1.251530
# country_rock         0.451172  1.247549
# roots_rock           0.459579  1.243757
# power_pop            0.475564  1.236546
# garage_rock          0.502664  1.224323
# hip_hop              0.540026  1.207471
# art_rock             0.569390  1.194226
# punk_rock            0.584126  1.187580
# ambient              0.612772  1.174659
# experimental         0.613780  1.174204
# blue_eyed_soul       0.617414  1.172565
# soft_rock            0.620835  1.171022
# bluegrass            0.630795  1.166530
# rock                 0.648879  1.158373
# classical            0.675184  1.146508
# pop_punk             0.681579  1.143624
# swing                0.683624  1.142701
# alternative_rock     0.683237  1.141327
# blues                0.715317  1.128406
# lo_fi                0.721063  1.125814
# avant_garde          0.742397  1.116192
# reggae               0.774028  1.101925
# new_wave             0.788070  1.095591
# grunge               0.841383  1.071544
# easy_listening       0.857881  1.064103
# funk                 0.863638  1.061506
# indie_rock           0.870879  1.058240
# folk_rock            0.910035  1.040579
# acoustic             0.976209  1.010731
# world                0.997536  1.001112

# %% [markdown]
# Rank genres (with frequency >= 50) by female-ness descending:

# %%
genre_stats[(genre_stats.frequency >= 50) & (genre_stats['f-skew'] > 1)].sort_values(['female%'], ascending = False)
# Out:
#                         frequency  female    male   female%     male%  \
# label
# vocal_jazz                     69    56.0    13.0  0.811594  0.188406
# dance_pop                     183   133.0    50.0  0.726776  0.273224
# dream_pop                      60    41.0    19.0  0.683333  0.316667
# electro_pop                   123    83.0    40.0  0.674797  0.325203
# dance                         307   204.0   103.0  0.664495  0.335505
# house                         143    94.0    49.0  0.657343  0.342657
# trip_hop                       70    45.0    25.0  0.642857  0.357143
# celtic                         62    39.0    23.0  0.629032  0.370968
# disco                         147    88.0    59.0  0.598639  0.401361
# indie_pop                     238   141.0    97.0  0.592437  0.407563
# contemporary                   96    52.0    44.0  0.541667  0.458333
# country_pop                    74    40.0    34.0  0.540541  0.459459
# neo_soul                       73    39.0    34.0  0.534247  0.465753
# traditional_pop                98    52.0    46.0  0.530612  0.469388
# soul                         1023   532.0   490.0  0.520039  0.478983
# musical                        51    26.0    25.0  0.509804  0.490196
# pop                          2617  1321.0  1294.0  0.504776  0.494459
# alternative                   120    58.0    62.0  0.483333  0.516667
# gospel                        346   162.0   184.0  0.468208  0.531792
# r_and_b                      1647   760.0   887.0  0.461445  0.538555
# electronica                   188    85.0   103.0  0.452128  0.547872
# chanson                        60    27.0    33.0  0.450000  0.550000
# indie                          98    42.0    56.0  0.428571  0.571429
# folk                         1046   427.0   616.0  0.408222  0.588910
# jazz                          962   392.0   570.0  0.407484  0.592516
# electronic                    224    90.0   134.0  0.401786  0.598214
# singer_songwriter              83    33.0    50.0  0.397590  0.602410
# americana                     270   101.0   169.0  0.374074  0.625926
# indie_folk                    102    38.0    64.0  0.372549  0.627451
# contemporary_christian         98    36.0    62.0  0.367347  0.632653
# synth_pop                     204    73.0   131.0  0.357843  0.642157
# pop_rock                      661   231.0   426.0  0.349470  0.644478
# christian                      76    25.0    51.0  0.328947  0.671053
# alternative_country           147    46.0   101.0  0.312925  0.687075
# country                      1613   504.0  1108.0  0.312461  0.686919
#
#                         max_list_length  min_list_length  mean_list_length  \
# label
# vocal_jazz                          9.0              1.0          2.927536
# dance_pop                           9.0              1.0          3.754098
# dream_pop                          10.0              1.0          4.100000
# electro_pop                        10.0              1.0          3.910569
# dance                              73.0              1.0          4.205212
# house                              14.0              1.0          4.195804
# trip_hop                           13.0              2.0          4.300000
# celtic                             11.0              1.0          3.338710
# disco                              73.0              1.0          5.061224
# indie_pop                          73.0              1.0          3.651261
# contemporary                       11.0              1.0          4.000000
# country_pop                         9.0              1.0          2.986486
# neo_soul                           12.0              1.0          4.602740
# traditional_pop                     8.0              1.0          3.081633
# soul                               13.0              1.0          3.894325
# musical                             7.0              1.0          3.137255
# pop                                73.0              1.0          3.065392
# alternative                        11.0              1.0          3.575000
# gospel                             12.0              1.0          3.936416
# r_and_b                            13.0              1.0          3.585914
# electronica                        15.0              1.0          4.430851
# chanson                             8.0              1.0          2.633333
# indie                               8.0              1.0          3.346939
# folk                               12.0              1.0          3.384468
# jazz                               12.0              1.0          3.415800
# electronic                         15.0              1.0          4.250000
# singer_songwriter                  12.0              1.0          3.506024
# americana                          12.0              1.0          4.133333
# indie_folk                         12.0              1.0          3.647059
# contemporary_christian             10.0              1.0          2.561224
# synth_pop                          73.0              1.0          4.823529
# pop_rock                           14.0              1.0          3.838661
# christian                          12.0              1.0          2.776316
# alternative_country                10.0              1.0          3.768707
# country                            12.0              1.0          2.358561
#
#                           f-skew    m-skew
# label
# vocal_jazz              2.610941  0.273386
# dance_pop               2.338076  0.396462
# dream_pop               2.198319  0.459499
# electro_pop             2.170856  0.471886
# dance                   2.137716  0.486834
# house                   2.114706  0.497213
# trip_hop                2.068105  0.518232
# celtic                  2.023630  0.538293
# disco                   1.925854  0.582394
# indie_pop               1.905901  0.591394
# contemporary            1.742570  0.665064
# country_pop             1.738947  0.666698
# neo_soul                1.718699  0.675831
# traditional_pop         1.707007  0.681105
# soul                    1.672993  0.695029
# musical                 1.640066  0.711299
# pop                     1.623892  0.717485
# alternative             1.554909  0.749709
# gospel                  1.506250  0.771656
# r_and_b                 1.484493  0.781470
# electronica             1.454518  0.794990
# chanson                 1.447674  0.798077
# indie                   1.378737  0.829171
# folk                    1.313271  0.854538
# jazz                    1.310899  0.859769
# electronic              1.292566  0.868038
# singer_songwriter       1.279069  0.874126
# americana               1.203416  0.908249
# indie_folk              1.198510  0.910462
# contemporary_christian  1.181774  0.918011
# synth_pop               1.151200  0.931801
# pop_rock                1.124265  0.935169
# christian               1.058241  0.973730
# alternative_country     1.006697  0.996979
# country                 1.005204  0.996753
